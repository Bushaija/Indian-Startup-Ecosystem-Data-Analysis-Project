# %% [markdown]
# ## This is a notebook to write python scripts to answer the hypothesis questions by visualizations

# %%
# %pip install prettytable
# Out:
# Collecting prettytable
#   Downloading prettytable-3.8.0-py3-none-any.whl (27 kB)
# Requirement already satisfied: wcwidth in c:\users\cynthia.mutisya\appdata\local\anaconda3\lib\site-packages (from prettytable) (0.2.5)
# Installing collected packages: prettytable
# Successfully installed prettytable-3.8.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.1 -> 23.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import matplotlib.pyplot as plt
from prettytable import PrettyTable

# %% [markdown]
# ## Import the complete Dataset from year 2018-2022

# %%
indian_startups= pd.read_excel('complete_data.xlsx')
indian_startups
# Out:
#          Company Name                 Sector       Stage    Amount  \
# 0     TheCollegeFever        Brand Marketing        Seed    250000
# 1     Happy Cow Dairy            Agriculture        Seed   5840000
# 2          MyLoanCare                 Credit    Series A   9490000
# 3         PayMe India     Financial Services       Angel   2000000
# 4            Eunimart   E-Commerce Platforms        Seed   3530000
# ...               ...                    ...         ...       ...
# 2841         Gigforce  Staffing & Recruiting  Pre-series   3000000
# 2842           Vahdam       Food & Beverages    Series C  20000000
# 2843     Leap Finance     Financial Services    Series C  55000000
# 2844     CollegeDekho                 EdTech    Series B  26000000
# 2845           WeRize     Financial Services    Series B   8000000
#
#      HeadQuarter  Year Funded         Investor  Founded
# 0      Bangalore         2018          Unknown      NaN
# 1         Mumbai         2018          Unknown      NaN
# 2        Gurgaon         2018          Unknown      NaN
# 3          Noida         2018          Unknown      NaN
# 4      Hyderabad         2018          Unknown      NaN
# ...          ...          ...              ...      ...
# 2841    Gurugram         2021  Endiya Partners   2019.0
# 2842   New Delhi         2021         IIFL AMC   2015.0
# 2843   Bangalore         2021     Owl Ventures   2019.0
# 2844    Gurugram         2021   Winter Capital   2015.0
# 2845   Bangalore         2021    3one4 Capital   2019.0
#
# [2846 rows x 8 columns]

# %% [markdown]
# ## Inspect the data structure of the whole data

# %%
indian_startups.info
# Out:
# <bound method DataFrame.info of          Company Name                 Sector       Stage    Amount  \
# 0     TheCollegeFever        Brand Marketing        Seed    250000
# 1     Happy Cow Dairy            Agriculture        Seed   5840000
# 2          MyLoanCare                 Credit    Series A   9490000
# 3         PayMe India     Financial Services       Angel   2000000
# 4            Eunimart   E-Commerce Platforms        Seed   3530000
# ...               ...                    ...         ...       ...
# 2841         Gigforce  Staffing & Recruiting  Pre-series   3000000
# 2842           Vahdam       Food & Beverages    Series C  20000000
# 2843     Leap Finance     Financial Services    Series C  55000000
# 2844     CollegeDekho                 EdTech    Series B  26000000
# 2845           WeRize     Financial Services    Series B   8000000
#
#      HeadQuarter  Year Funded         Investor  Founded
# 0      Bangalore         2018          Unknown      NaN
# 1         Mumbai         2018          Unknown      NaN
# 2        Gurgaon         2018          Unknown      NaN
# 3          Noida         2018          Unknown      NaN
# 4      Hyderabad         2018          Unknown      NaN
# ...          ...          ...              ...      ...
# 2841    Gurugram         2021  Endiya Partners   2019.0
# 2842   New Delhi         2021         IIFL AMC   2015.0
# 2843   Bangalore         2021     Owl Ventures   2019.0
# 2844    Gurugram         2021   Winter Capital   2015.0
# 2845   Bangalore         2021    3one4 Capital   2019.0
#
# [2846 rows x 8 columns]>

# %% [markdown]
# ## Answering the questions the formulated 5 SMART questions:
# 1. What is the overall trend in funding received by start-ups in India from 2018 to 2021?
# 2. Which industries or sectors have received the highest funding during this period?
# 3. What is the distribution of startups across the cities in India?
# 4. What is the average funding amount received by start-ups in India during this period?
# 5. Is there a correlation between the funding amount and the number of investors involved in funding rounds?

# %% [markdown]
# ## Question 1
# ### What is the overall trend in funding received by start ups in India from 2018-2021

# %% [markdown]
# #### In this we visualize the total funding against the years

# %%
total_funding_per_year = indian_startups.groupby('Year Funded')['Amount'].sum()


# Calculate the mean funding for each year
total_funding_per_year = indian_startups.groupby('Year Funded')['Amount'].mean()

# Extract the years and mean funding data for plotting
years = total_funding_per_year.index
total_funding = total_funding_per_year.values

# Create the plot
plt.figure(figsize=(10, 6))  # Optional: Set the size of the figure

# Plot the mean funding against years using a line graph
plt.plot(years, total_funding, marker='o', linestyle='-')

# Add labels and title
plt.xlabel('Year Funded')
plt.ylabel('Total Funding Amount')
plt.title('Total Funding Amount vs. Year Funded')

# Optional: Customize the appearance (e.g., grid, axis limits, etc.)
plt.grid(True)
plt.xlim(min(years) - 1, max(years) + 1)  # Set the x-axis limits with some padding
plt.ylim(0, max(total_funding) * 1.1)  # Set the y-axis limits with some padding

# Show the plot
plt.show()

# %% [markdown]
# ## In this we visualize the total funding amount against the years

# %%
mean_funding_per_year = indian_startups.groupby('Year Funded')['Amount'].mean()


# Calculate the mean funding for each year
mean_funding_per_year = indian_startups.groupby('Year Funded')['Amount'].mean()

# Extract the years and mean funding data for plotting
years = mean_funding_per_year.index
mean_funding = mean_funding_per_year.values

# Create the plot
plt.figure(figsize=(10, 6))  # Optional: Set the size of the figure

# Plot the mean funding against years using a line graph
plt.plot(years, mean_funding, marker='o', linestyle='-')

# Add labels and title
plt.xlabel('Year Funded')
plt.ylabel('Mean Funding Amount')
plt.title('Mean Funding Amount vs. Year Funded')

# Optional: Customize the appearance (e.g., grid, axis limits, etc.)
plt.grid(True)
plt.xlim(min(years) - 1, max(years) + 1)  # Set the x-axis limits with some padding
plt.ylim(0, max(mean_funding) * 1.1)  # Set the y-axis limits with some padding

# Show the plot
plt.show()

# %% [markdown]
# ## Question 2
#
# ### Which industries or sectors have received the highest funding during this period?

# %% [markdown]
# ### We analyze this according to years in mean and sum
#
# ### Sum
# ### Year 2018

# %%
funding_2018 = indian_startups[indian_startups['Year Funded'] == 2018]

# Group by 'Sector' and calculate total funding for each sector
group2018_total_funding_per_sector = funding_2018.groupby('Sector')['Amount'].sum()

# Sort sectors based on total funding in descending order
sorted_sectors2018 = group2018_total_funding_per_sector.sort_values(ascending=False)

# Get the top 5 sectors
top_5_sectors = sorted_sectors2018.head(5)

print(top_5_sectors)
# Out:
# Sector
# Financial Services    2968775000
# Aerospace             2923530000
# Food Delivery         1224490000
# Finance                901262000
# Banking                862990000
# Name: Amount, dtype: int64

# %% [markdown]
# ### Year 2019

# %%
funding_2019 = indian_startups[indian_startups['Year Funded'] == 2019]

# Group by 'Sector' and calculate total funding for each sector
group2019_total_funding_per_sector = funding_2019.groupby('Sector')['Amount'].sum()

# Sort sectors based on total funding in descending order
sorted_sectors2019 = group2019_total_funding_per_sector.sort_values(ascending=False)

# Get the top 5 sectors
top_5_sectors2019 = sorted_sectors2019.head(5)

print(top_5_sectors2019)
# Out:
# Sector
# Automobile    113000000
# Food           73400000
# Technology     58000000
# Logistics      56000000
# Ai             51000000
# Name: Amount, dtype: int64

# %% [markdown]
# ### Year 2020

# %%
funding_2020 = indian_startups[indian_startups['Year Funded'] == 2020]

# Group by 'Sector' and calculate total funding for each sector
group2020_total_funding_per_sector = funding_2020.groupby('Sector')['Amount'].sum()

# Sort sectors based on total funding in descending order
sorted_sectors2020 = group2020_total_funding_per_sector.sort_values(ascending=False)

# Get the top 5 sectors
top_5_sectors2020 = sorted_sectors2020.head(5)

top_5_sectors2020
# Out:
# Sector
# Retail                                70239400000
# Tech company                           3028700000
# Multinational conglomerate company     2200000000
# Edtech                                 1471442030
# E-commerce                             1273607000
# Name: Amount, dtype: int64

# %% [markdown]
# ### Year 2021

# %%
funding_2021 = indian_startups[indian_startups['Year Funded'] == 2021]

# Group by 'Sector' and calculate total funding for each sector
group2021_total_funding_per_sector = funding_2021.groupby('Sector')['Amount'].sum()

# Sort sectors based on total funding in descending order
sorted_sectors2021 = group2021_total_funding_per_sector.sort_values(ascending=False)

# Get the top 5 sectors
top_5_sectors2021 = sorted_sectors2021.head(5)

top_5_sectors2021
# Out:
# Sector
# FinTech               152656480000
# EdTech                  2001030000
# Automotive              1919700000
# Financial Services      1564450000
# E-commerce              1336445000
# Name: Amount, dtype: int64

# %% [markdown]
# ### Overall Sum and amount in all years

# %%
# Group by 'Sector' and calculate total funding for each sector
total_funding_per_sector = indian_startups.groupby('Sector')['Amount'].sum()

# Sort sectors based on total funding in descending order
sorted_sectors = total_funding_per_sector.sort_values(ascending=False)

# Get the top 5 sectors
top_5_sectors_overall = sorted_sectors.head(5)

# Create a table to display the top 5 sectors based on total funding
table = PrettyTable()
table.field_names = ['Sector', 'Total Funding']

for sector, funding in top_5_sectors_overall.items():
    table.add_row([sector, f"${funding:,.2f}"])

print(table)
# Out:
# +--------------------+---------------------+
# |       Sector       |    Total Funding    |
# +--------------------+---------------------+
# |      FinTech       | $153,932,010,000.00 |
# |       Retail       |  $70,549,410,000.00 |
# | Financial Services |  $4,656,225,000.00  |
# |       EdTech       |  $3,829,415,000.00  |
# |    Tech company    |  $3,028,700,000.00  |
# +--------------------+---------------------+

# %% [markdown]
# ### Overall mean funding in sectors in all years

# %%
# Group by 'Sector' and calculate total funding for each sector
mean_funding_per_sector = indian_startups.groupby('Sector')['Amount'].mean()

# Sort sectors based on total funding in descending order
mean_sorted_sectors = mean_funding_per_sector.sort_values(ascending=False)

# Get the top 5 sectors
top_5_sectors_overall_mean = mean_sorted_sectors.head(5)

# Create a table to display the top 5 sectors based on total funding
table = PrettyTable()
table.field_names = ['Sector', 'Mean Funding']

for sector, funding in top_5_sectors_overall_mean.items():
    table.add_row([sector, f"${funding:,.2f}"])

print(table)
# Out:
# +------------------------------------+-------------------+
# |               Sector               |    Mean Funding   |
# +------------------------------------+-------------------+
# |               Retail               | $2,713,438,846.15 |
# | Multinational conglomerate company | $2,200,000,000.00 |
# |             Aerospace              | $1,461,765,000.00 |
# |       Innovation Management        | $1,000,000,000.00 |
# |              FinTech               |  $884,666,724.14  |
# +------------------------------------+-------------------+

# %% [markdown]
# ## Question 3
# ### What is the distribution of startups across the cities in India?
#
# ### In this we count the number of startups in each sector and use a bar graph to visualize

# %%
# Group by 'HeadQuarter' and calculate the number of startups in each headquarters
startup_count_per_hq = indian_startups.groupby('HeadQuarter').size().reset_index(name='Startup Count')

# Sort the DataFrame by 'Startup Count' in descending order
startup_count_per_hq_sorted = startup_count_per_hq.sort_values(by='Startup Count', ascending=False)

startup_count_per_hq_sorted=startup_count_per_hq_sorted.head(10)

# %%
# Construct a histogram to visualize the number of startups in each headquarters
plt.figure(figsize=(10, 6))
plt.bar(startup_count_per_hq_sorted['HeadQuarter'], startup_count_per_hq_sorted['Startup Count'])
plt.xlabel('HeadQuarter')
plt.ylabel('Startup Count')
plt.title('Number of Startups in Each Headquarters')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Question 4
#
# ### What is the average funding amount received by start-ups in India during this period?

# %% [markdown]
# ## Question 5
#
# ### Is there a correlation between the funding amount and the number of investors involved in funding rounds?

# %%
# investors and the number of startups funded
investors_summary = indian_startups.groupby('Investor').size().reset_index(name='Startup Count')
investors_summary=investors_summary.sort_values(by='Startup Count',ascending=False)
investors_summary=investors_summary.head(10)
investors_summary
# Out:
#                        Investor  Startup Count
# 1358                    Unknown            589
# 1345                Undisclosed             51
# 1373          Venture Catalysts             44
# 587   Inflection Point Ventures             40
# 1315              Titan Capital             21
# 837       Mumbai Angels Network             20
# 1302               Tiger Global             20
# 1128      Sequoia Capital India             17
# 1441               Y Combinator             17
# 130             Angel investors             15

# %%
# funding amou
startup_count_per_hq = indian_startups.groupby('HeadQuarter').size().reset_index(name='Startup Count')

# Sort the DataFrame by 'Startup Count' in descending order
startup_count_per_hq_sorted = startup_count_per_hq.sort_values(by='Startup Count', ascending=False)

startup_count_per_hq_sorted=startup_count_per_hq_sorted.head(10)
